# %%
# face verification with the VGGFace2 model
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from scipy.spatial.distance import cosine
from mtcnn.mtcnn import MTCNN
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input

# extract a single face from a given photograph
def extract_face(filename, required_size=(224, 224)):
    # load image from file
#     pixels = pyplot.imread(filename)
#     # create the detector, using default weights
#     detector = MTCNN()
#     # detect faces in the image
#     results = detector.detect_faces(pixels)
#     # extract the bounding box from the first face
#     x1, y1, width, height = results[0]['box']
#     x2, y2 = x1 + width, y1 + height
#     # extract the face
#     face = pixels[y1:y2, x1:x2]
    # resize pixels to the model size
    image = Image.open(filename)
    image = image.resize(required_size)
    face_array = asarray(image)
    return face_array

model = None
# extract faces and calculate face embeddings for a list of photo files
def get_embeddings(filenames):
    # extract faces
    faces = [extract_face(f) for f in filenames]
    # convert into an array of samples
    samples = asarray(faces, 'float32')
    # prepare the face for the model, e.g. center pixels
    samples = preprocess_input(samples, version=2)
    # create a vggface model
    global model
    if not model:
        model = VGGFace(model='resnet50', include_top=False, input_shape=(224, 224, 3), pooling='avg')
    # perform prediction
    yhat = model.predict(samples)
    return yhat

# determine if a candidate face is a match for a known face
def is_match(known_embedding, candidate_embedding, thresh=0.5):
    # calculate distance between embeddings
    score = cosine(known_embedding, candidate_embedding)
    if score <= thresh:
        print('>face is a Match (%.3f <= %.3f)' % (score, thresh))
        return True, score
    else:
        print('>face is NOT a Match (%.3f > %.3f)' % (score, thresh))
        return False, score

# %%
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import pandas as pd

# %%
BASE_PATH = pathlib.Path('../data/mfr2')
labels_path = BASE_PATH / 'mfr2_labels.txt'
pairs_path = BASE_PATH / 'pairs.txt'

# %%
labels=pd.read_csv(filepath_or_buffer=str(labels_path))

# %%
with pairs_path.open() as f:
    pairs_data = [l.strip().split(' ') for l in f.readlines() if l.strip()]

pairs = []
for pair_data in pairs_data:
    if len(pair_data) == 3:
        pairs.append(((pair_data[0], pair_data[1]), (pair_data[0], pair_data[2])))
    elif len(pair_data) == 4:
        pairs.append(((pair_data[0], pair_data[1]), (pair_data[2], pair_data[3])))
    else:
        print('wtf', pair_data)

# %%
pairs[1]
# Out:
# (('ImranKhan', '2'), ('SimonCowell', '3'))

# %%
results = []

# positive test
for pair in pairs:
    (person1,index1),(person2,index2) = pair
    path1 = BASE_PATH / person1 / f'{person1}_{str(index1).rjust(4, "0")}.png'
    path2 = BASE_PATH / person2 / f'{person2}_{str(index2).rjust(4, "0")}.png'
    
#     try:
    features1,features2=get_embeddings([path1, path2])
    matched, distance = is_match(features1, features2)
#     except Exception as e:
#         print(e)
#         continue
    
    results.append([pair, matched, distance])
# Out:
# >face is a Match (0.248 <= 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is a Match (0.386 <= 0.500)
# >face is a Match (0.481 <= 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is a Match (0.408 <= 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.698 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is a Match (0.371 <= 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is a Match (0.203 <= 0.500)
# >face is a Match (0.392 <= 0.500)
# >face is a Match (0.228 <= 0.500)
# >face is NOT a Match (0.504 > 0.500)
# >face is a Match (0.361 <= 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.644 > 0.500)
# >face is a Match (0.301 <= 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is a Match (0.455 <= 0.500)
# >face is a Match (0.410 <= 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.778 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.630 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.658 > 0.500)
# >face is NOT a Match (0.746 > 0.500)
# >face is a Match (0.389 <= 0.500)
# >face is a Match (0.222 <= 0.500)
# >face is a Match (0.472 <= 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is a Match (0.203 <= 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.587 > 0.500)
# >face is NOT a Match (0.589 > 0.500)
# >face is a Match (0.246 <= 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is a Match (0.268 <= 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is a Match (0.145 <= 0.500)
# >face is NOT a Match (0.619 > 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is NOT a Match (0.562 > 0.500)
# >face is NOT a Match (0.746 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.535 > 0.500)
# >face is NOT a Match (0.628 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.881 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.707 > 0.500)
# >face is a Match (0.367 <= 0.500)
# >face is a Match (0.260 <= 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is a Match (0.265 <= 0.500)
# >face is NOT a Match (0.501 > 0.500)
# >face is NOT a Match (0.631 > 0.500)
# >face is a Match (0.500 <= 0.500)
# >face is a Match (0.377 <= 0.500)
# >face is a Match (0.364 <= 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is a Match (0.388 <= 0.500)
# >face is a Match (0.293 <= 0.500)
# >face is NOT a Match (0.853 > 0.500)
# >face is a Match (0.262 <= 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is a Match (0.462 <= 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.685 > 0.500)
# >face is a Match (0.243 <= 0.500)
# >face is a Match (0.415 <= 0.500)
# >face is NOT a Match (0.598 > 0.500)
# >face is NOT a Match (0.843 > 0.500)
# >face is NOT a Match (0.561 > 0.500)
# >face is a Match (0.132 <= 0.500)
# >face is NOT a Match (0.832 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is a Match (0.227 <= 0.500)
# >face is a Match (0.374 <= 0.500)
# >face is a Match (0.243 <= 0.500)
# >face is a Match (0.159 <= 0.500)
# >face is a Match (0.469 <= 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.579 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is a Match (0.293 <= 0.500)
# >face is NOT a Match (0.871 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is a Match (0.182 <= 0.500)
# >face is a Match (0.275 <= 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is a Match (0.491 <= 0.500)
# >face is NOT a Match (0.712 > 0.500)
# >face is NOT a Match (0.559 > 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is a Match (0.171 <= 0.500)
# >face is a Match (0.373 <= 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is a Match (0.465 <= 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is a Match (0.358 <= 0.500)
# >face is a Match (0.168 <= 0.500)
# >face is a Match (0.359 <= 0.500)
# >face is a Match (0.254 <= 0.500)
# >face is NOT a Match (0.682 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.735 > 0.500)
# >face is a Match (0.294 <= 0.500)
# >face is NOT a Match (0.818 > 0.500)
# >face is a Match (0.402 <= 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is a Match (0.274 <= 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is a Match (0.364 <= 0.500)
# >face is NOT a Match (0.573 > 0.500)
# >face is a Match (0.482 <= 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is a Match (0.401 <= 0.500)
# >face is a Match (0.268 <= 0.500)
# >face is NOT a Match (0.859 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.543 > 0.500)
# >face is a Match (0.268 <= 0.500)
# >face is NOT a Match (0.817 > 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is a Match (0.157 <= 0.500)
# >face is a Match (0.271 <= 0.500)
# >face is NOT a Match (0.773 > 0.500)
# >face is a Match (0.475 <= 0.500)
# >face is NOT a Match (0.720 > 0.500)
# >face is a Match (0.111 <= 0.500)
# >face is NOT a Match (0.540 > 0.500)
# >face is NOT a Match (0.502 > 0.500)
# >face is NOT a Match (0.551 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is a Match (0.445 <= 0.500)
# >face is a Match (0.406 <= 0.500)
# >face is NOT a Match (0.795 > 0.500)
# >face is NOT a Match (0.688 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is a Match (0.284 <= 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is a Match (0.248 <= 0.500)
# >face is a Match (0.211 <= 0.500)
# >face is NOT a Match (0.769 > 0.500)
# >face is a Match (0.191 <= 0.500)
# >face is a Match (0.484 <= 0.500)
# >face is a Match (0.355 <= 0.500)
# >face is a Match (0.196 <= 0.500)
# >face is NOT a Match (0.643 > 0.500)
# >face is NOT a Match (0.708 > 0.500)
# >face is NOT a Match (0.691 > 0.500)
# >face is a Match (0.176 <= 0.500)
# >face is a Match (0.170 <= 0.500)
# >face is NOT a Match (0.837 > 0.500)
# >face is a Match (0.253 <= 0.500)
# >face is NOT a Match (0.505 > 0.500)
# >face is NOT a Match (0.829 > 0.500)
# >face is a Match (0.468 <= 0.500)
# >face is a Match (0.450 <= 0.500)
# >face is NOT a Match (0.510 > 0.500)
# >face is NOT a Match (0.505 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is a Match (0.280 <= 0.500)
# >face is NOT a Match (0.562 > 0.500)
# >face is NOT a Match (0.682 > 0.500)
# >face is a Match (0.294 <= 0.500)
# >face is NOT a Match (0.705 > 0.500)
# >face is NOT a Match (0.535 > 0.500)
# >face is a Match (0.306 <= 0.500)
# >face is NOT a Match (0.577 > 0.500)
# >face is a Match (0.122 <= 0.500)
# >face is NOT a Match (0.773 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is a Match (0.217 <= 0.500)
# >face is a Match (0.199 <= 0.500)
# >face is NOT a Match (0.507 > 0.500)
# >face is NOT a Match (0.533 > 0.500)
# >face is a Match (0.106 <= 0.500)
# >face is a Match (0.219 <= 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is a Match (0.396 <= 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is a Match (0.421 <= 0.500)
# >face is NOT a Match (0.732 > 0.500)
# >face is NOT a Match (0.649 > 0.500)
# >face is NOT a Match (0.527 > 0.500)
# >face is NOT a Match (0.614 > 0.500)
# >face is a Match (0.428 <= 0.500)
# >face is a Match (0.203 <= 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is a Match (0.314 <= 0.500)
# >face is a Match (0.351 <= 0.500)
# >face is a Match (0.397 <= 0.500)
# >face is a Match (0.411 <= 0.500)
# >face is a Match (0.281 <= 0.500)
# >face is a Match (0.330 <= 0.500)
# >face is NOT a Match (0.831 > 0.500)
# >face is a Match (0.357 <= 0.500)
# >face is a Match (0.444 <= 0.500)
# >face is a Match (0.397 <= 0.500)
# >face is a Match (0.219 <= 0.500)
# >face is a Match (0.494 <= 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is a Match (0.397 <= 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is a Match (0.362 <= 0.500)
# >face is NOT a Match (0.859 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is a Match (0.359 <= 0.500)
# >face is NOT a Match (0.781 > 0.500)
# >face is a Match (0.447 <= 0.500)
# >face is a Match (0.497 <= 0.500)
# >face is a Match (0.463 <= 0.500)
# >face is NOT a Match (0.607 > 0.500)
# >face is NOT a Match (0.825 > 0.500)
# >face is NOT a Match (0.727 > 0.500)
# >face is NOT a Match (0.645 > 0.500)
# >face is NOT a Match (0.631 > 0.500)
# >face is NOT a Match (0.613 > 0.500)
# >face is a Match (0.265 <= 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.642 > 0.500)
# >face is NOT a Match (0.527 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is a Match (0.472 <= 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is NOT a Match (0.726 > 0.500)
# >face is a Match (0.151 <= 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.573 > 0.500)
# >face is a Match (0.333 <= 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is a Match (0.355 <= 0.500)
# >face is NOT a Match (0.519 > 0.500)
# >face is a Match (0.403 <= 0.500)
# >face is NOT a Match (0.878 > 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is a Match (0.440 <= 0.500)
# >face is NOT a Match (0.560 > 0.500)
# >face is NOT a Match (0.672 > 0.500)
# >face is NOT a Match (0.793 > 0.500)
# >face is NOT a Match (0.582 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is a Match (0.147 <= 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.504 > 0.500)
# >face is a Match (0.379 <= 0.500)
# >face is a Match (0.309 <= 0.500)
# >face is NOT a Match (0.700 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.508 > 0.500)
# >face is a Match (0.401 <= 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is a Match (0.452 <= 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.783 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is a Match (0.459 <= 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.623 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is a Match (0.468 <= 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is a Match (0.333 <= 0.500)
# >face is a Match (0.477 <= 0.500)
# >face is a Match (0.317 <= 0.500)
# >face is a Match (0.465 <= 0.500)
# >face is NOT a Match (0.618 > 0.500)
# >face is NOT a Match (0.721 > 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is a Match (0.098 <= 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.519 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is a Match (0.260 <= 0.500)
# >face is NOT a Match (0.702 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is a Match (0.155 <= 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is NOT a Match (0.670 > 0.500)
# >face is NOT a Match (0.674 > 0.500)
# >face is NOT a Match (0.582 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is a Match (0.284 <= 0.500)
# >face is a Match (0.200 <= 0.500)
# >face is NOT a Match (0.554 > 0.500)
# >face is a Match (0.443 <= 0.500)
# >face is a Match (0.111 <= 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.830 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is a Match (0.376 <= 0.500)
# >face is a Match (0.310 <= 0.500)
# >face is NOT a Match (0.584 > 0.500)
# >face is a Match (0.416 <= 0.500)
# >face is a Match (0.436 <= 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.504 > 0.500)
# >face is NOT a Match (0.667 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.501 > 0.500)
# >face is a Match (0.310 <= 0.500)
# >face is a Match (0.443 <= 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is NOT a Match (0.749 > 0.500)
# >face is NOT a Match (0.634 > 0.500)
# >face is a Match (0.347 <= 0.500)
# >face is a Match (0.302 <= 0.500)
# >face is a Match (0.180 <= 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.520 > 0.500)
# >face is NOT a Match (0.567 > 0.500)
# >face is a Match (0.344 <= 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.784 > 0.500)
# >face is a Match (0.455 <= 0.500)
# >face is NOT a Match (0.829 > 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is a Match (0.258 <= 0.500)
# >face is a Match (0.246 <= 0.500)
# >face is NOT a Match (0.684 > 0.500)
# >face is a Match (0.322 <= 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.681 > 0.500)
# >face is NOT a Match (0.534 > 0.500)
# >face is NOT a Match (0.539 > 0.500)
# >face is a Match (0.406 <= 0.500)
# >face is a Match (0.250 <= 0.500)
# >face is NOT a Match (0.769 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is a Match (0.478 <= 0.500)
# >face is NOT a Match (0.742 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.569 > 0.500)
# >face is NOT a Match (0.530 > 0.500)
# >face is NOT a Match (0.712 > 0.500)
# >face is a Match (0.279 <= 0.500)
# >face is a Match (0.449 <= 0.500)
# >face is a Match (0.138 <= 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is a Match (0.309 <= 0.500)
# >face is a Match (0.383 <= 0.500)
# >face is NOT a Match (0.578 > 0.500)
# >face is a Match (0.254 <= 0.500)
# >face is a Match (0.311 <= 0.500)
# >face is NOT a Match (0.848 > 0.500)
# >face is a Match (0.411 <= 0.500)
# >face is NOT a Match (0.671 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.683 > 0.500)
# >face is NOT a Match (0.793 > 0.500)
# >face is NOT a Match (0.702 > 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is a Match (0.159 <= 0.500)
# >face is a Match (0.200 <= 0.500)
# >face is NOT a Match (0.628 > 0.500)
# >face is a Match (0.292 <= 0.500)
# >face is NOT a Match (0.526 > 0.500)
# >face is a Match (0.275 <= 0.500)
# >face is NOT a Match (0.650 > 0.500)
# >face is NOT a Match (0.726 > 0.500)
# >face is NOT a Match (0.639 > 0.500)
# >face is a Match (0.325 <= 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is a Match (0.441 <= 0.500)
# >face is NOT a Match (0.794 > 0.500)
# >face is a Match (0.447 <= 0.500)
# >face is NOT a Match (0.623 > 0.500)
# >face is a Match (0.182 <= 0.500)
# >face is a Match (0.110 <= 0.500)
# >face is a Match (0.170 <= 0.500)
# >face is NOT a Match (0.516 > 0.500)
# >face is a Match (0.340 <= 0.500)
# >face is a Match (0.332 <= 0.500)
# >face is a Match (0.445 <= 0.500)
# >face is NOT a Match (0.545 > 0.500)
# >face is a Match (0.331 <= 0.500)
# >face is a Match (0.102 <= 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is a Match (0.190 <= 0.500)
# >face is a Match (0.229 <= 0.500)
# >face is a Match (0.282 <= 0.500)
# >face is a Match (0.261 <= 0.500)
# >face is a Match (0.486 <= 0.500)
# >face is NOT a Match (0.562 > 0.500)
# >face is a Match (0.085 <= 0.500)
# >face is a Match (0.267 <= 0.500)
# >face is a Match (0.361 <= 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is a Match (0.347 <= 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is a Match (0.284 <= 0.500)
# >face is a Match (0.271 <= 0.500)
# >face is a Match (0.381 <= 0.500)
# >face is a Match (0.275 <= 0.500)
# >face is a Match (0.332 <= 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is a Match (0.417 <= 0.500)
# >face is a Match (0.425 <= 0.500)
# >face is NOT a Match (0.633 > 0.500)
# >face is a Match (0.240 <= 0.500)
# >face is NOT a Match (0.564 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.707 > 0.500)
# >face is a Match (0.260 <= 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is a Match (0.335 <= 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is a Match (0.268 <= 0.500)
# >face is a Match (0.411 <= 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.532 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.848 > 0.500)
# >face is NOT a Match (0.757 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.699 > 0.500)
# >face is a Match (0.271 <= 0.500)
# >face is a Match (0.267 <= 0.500)
# >face is NOT a Match (0.695 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is a Match (0.313 <= 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.585 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.529 > 0.500)
# >face is NOT a Match (0.726 > 0.500)
# >face is a Match (0.285 <= 0.500)
# >face is a Match (0.391 <= 0.500)
# >face is a Match (0.442 <= 0.500)
# >face is NOT a Match (0.794 > 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is a Match (0.363 <= 0.500)
# >face is a Match (0.463 <= 0.500)
# >face is NOT a Match (0.620 > 0.500)
# >face is a Match (0.280 <= 0.500)
# >face is a Match (0.188 <= 0.500)
# >face is a Match (0.345 <= 0.500)
# >face is NOT a Match (0.549 > 0.500)
# >face is a Match (0.321 <= 0.500)
# >face is a Match (0.257 <= 0.500)
# >face is NOT a Match (0.655 > 0.500)
# >face is a Match (0.392 <= 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is a Match (0.297 <= 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is a Match (0.241 <= 0.500)
# >face is NOT a Match (0.823 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.617 > 0.500)
# >face is a Match (0.315 <= 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is a Match (0.292 <= 0.500)
# >face is a Match (0.370 <= 0.500)
# >face is a Match (0.221 <= 0.500)
# >face is NOT a Match (0.607 > 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.851 > 0.500)
# >face is NOT a Match (0.848 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is a Match (0.143 <= 0.500)
# >face is NOT a Match (0.829 > 0.500)
# >face is a Match (0.419 <= 0.500)
# >face is a Match (0.393 <= 0.500)
# >face is NOT a Match (0.577 > 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is a Match (0.414 <= 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is a Match (0.137 <= 0.500)
# >face is a Match (0.305 <= 0.500)
# >face is a Match (0.415 <= 0.500)
# >face is a Match (0.396 <= 0.500)
# >face is a Match (0.148 <= 0.500)
# >face is a Match (0.334 <= 0.500)
# >face is a Match (0.353 <= 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is NOT a Match (0.723 > 0.500)
# >face is a Match (0.391 <= 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.794 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.736 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is a Match (0.236 <= 0.500)
# >face is a Match (0.150 <= 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.569 > 0.500)
# >face is a Match (0.141 <= 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.764 > 0.500)
# >face is NOT a Match (0.844 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.624 > 0.500)
# >face is NOT a Match (0.542 > 0.500)
# >face is a Match (0.173 <= 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is a Match (0.419 <= 0.500)
# >face is NOT a Match (0.807 > 0.500)
# >face is a Match (0.289 <= 0.500)
# >face is NOT a Match (0.620 > 0.500)
# >face is NOT a Match (0.654 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is a Match (0.317 <= 0.500)
# >face is a Match (0.495 <= 0.500)
# >face is NOT a Match (0.625 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is a Match (0.395 <= 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is a Match (0.298 <= 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is a Match (0.494 <= 0.500)
# >face is a Match (0.304 <= 0.500)
# >face is a Match (0.296 <= 0.500)
# >face is NOT a Match (0.679 > 0.500)
# >face is a Match (0.422 <= 0.500)
# >face is a Match (0.215 <= 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is NOT a Match (0.626 > 0.500)
# >face is a Match (0.169 <= 0.500)
# >face is a Match (0.338 <= 0.500)
# >face is a Match (0.355 <= 0.500)
# >face is a Match (0.358 <= 0.500)
# >face is a Match (0.363 <= 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.686 > 0.500)
# >face is NOT a Match (0.612 > 0.500)
# >face is a Match (0.480 <= 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is a Match (0.291 <= 0.500)
# >face is a Match (0.356 <= 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.541 > 0.500)
# >face is a Match (0.228 <= 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is a Match (0.439 <= 0.500)
# >face is a Match (0.216 <= 0.500)
# >face is a Match (0.403 <= 0.500)
# >face is NOT a Match (0.571 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is a Match (0.405 <= 0.500)
# >face is NOT a Match (0.810 > 0.500)
# >face is NOT a Match (0.861 > 0.500)
# >face is a Match (0.202 <= 0.500)
# >face is a Match (0.333 <= 0.500)
# >face is NOT a Match (0.593 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.507 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.590 > 0.500)
# >face is NOT a Match (0.830 > 0.500)
# >face is a Match (0.373 <= 0.500)
# >face is NOT a Match (0.743 > 0.500)
# >face is a Match (0.330 <= 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is a Match (0.422 <= 0.500)
# >face is a Match (0.305 <= 0.500)
# >face is NOT a Match (0.527 > 0.500)
# >face is NOT a Match (0.724 > 0.500)
# >face is a Match (0.468 <= 0.500)
# >face is NOT a Match (0.680 > 0.500)
# >face is a Match (0.172 <= 0.500)
# >face is NOT a Match (0.624 > 0.500)
# >face is a Match (0.178 <= 0.500)
# >face is NOT a Match (0.626 > 0.500)
# >face is a Match (0.376 <= 0.500)
# >face is a Match (0.278 <= 0.500)
# >face is NOT a Match (0.696 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.662 > 0.500)
# >face is NOT a Match (0.685 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is a Match (0.427 <= 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is a Match (0.273 <= 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is a Match (0.422 <= 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is a Match (0.195 <= 0.500)
# >face is a Match (0.377 <= 0.500)
# >face is a Match (0.245 <= 0.500)
# >face is a Match (0.303 <= 0.500)
# >face is NOT a Match (0.812 > 0.500)
# >face is a Match (0.369 <= 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is a Match (0.315 <= 0.500)
# >face is NOT a Match (0.620 > 0.500)
# >face is a Match (0.176 <= 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.621 > 0.500)
# >face is a Match (0.493 <= 0.500)
# >face is NOT a Match (0.528 > 0.500)
# >face is NOT a Match (0.627 > 0.500)
# >face is a Match (0.163 <= 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is a Match (0.251 <= 0.500)
# >face is a Match (0.275 <= 0.500)
# >face is NOT a Match (0.631 > 0.500)
# >face is NOT a Match (0.760 > 0.500)
# >face is NOT a Match (0.632 > 0.500)
# >face is NOT a Match (0.502 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.639 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is a Match (0.396 <= 0.500)
# >face is a Match (0.180 <= 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is a Match (0.459 <= 0.500)
# >face is NOT a Match (0.547 > 0.500)
# >face is a Match (0.240 <= 0.500)
# >face is NOT a Match (0.592 > 0.500)
# >face is a Match (0.223 <= 0.500)
# >face is NOT a Match (0.759 > 0.500)
# >face is NOT a Match (0.735 > 0.500)
# >face is a Match (0.245 <= 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.542 > 0.500)
# >face is a Match (0.427 <= 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is a Match (0.254 <= 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.831 > 0.500)
# >face is NOT a Match (0.719 > 0.500)
# >face is a Match (0.257 <= 0.500)
# >face is NOT a Match (0.599 > 0.500)
# >face is NOT a Match (0.714 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is a Match (0.167 <= 0.500)
# >face is NOT a Match (0.737 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.699 > 0.500)
# >face is a Match (0.438 <= 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.684 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is a Match (0.192 <= 0.500)
# >face is a Match (0.167 <= 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is a Match (0.480 <= 0.500)
# >face is NOT a Match (0.605 > 0.500)
# >face is a Match (0.462 <= 0.500)
# >face is a Match (0.251 <= 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is a Match (0.445 <= 0.500)
# >face is a Match (0.239 <= 0.500)
# >face is a Match (0.392 <= 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.742 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is a Match (0.468 <= 0.500)
# >face is a Match (0.406 <= 0.500)
# >face is a Match (0.262 <= 0.500)
# >face is NOT a Match (0.664 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.812 > 0.500)
# >face is NOT a Match (0.543 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is a Match (0.396 <= 0.500)
# >face is NOT a Match (0.795 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.810 > 0.500)
# >face is a Match (0.104 <= 0.500)
# >face is a Match (0.304 <= 0.500)
# >face is NOT a Match (0.784 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.585 > 0.500)
# >face is NOT a Match (0.795 > 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.598 > 0.500)
# >face is a Match (0.191 <= 0.500)
# >face is a Match (0.170 <= 0.500)
# >face is a Match (0.466 <= 0.500)
# >face is a Match (0.432 <= 0.500)
# >face is a Match (0.444 <= 0.500)
# >face is NOT a Match (0.760 > 0.500)
# >face is NOT a Match (0.503 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.756 > 0.500)
# >face is NOT a Match (0.708 > 0.500)
# >face is a Match (0.399 <= 0.500)
# >face is NOT a Match (0.666 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is NOT a Match (0.514 > 0.500)
# >face is a Match (0.298 <= 0.500)
# >face is NOT a Match (0.695 > 0.500)
# >face is a Match (0.482 <= 0.500)
# >face is NOT a Match (0.578 > 0.500)
# >face is NOT a Match (0.596 > 0.500)
# >face is a Match (0.240 <= 0.500)
# >face is a Match (0.299 <= 0.500)
# >face is a Match (0.340 <= 0.500)
# >face is a Match (0.452 <= 0.500)
# >face is NOT a Match (0.607 > 0.500)
# >face is NOT a Match (0.589 > 0.500)
# >face is a Match (0.416 <= 0.500)
# >face is NOT a Match (0.735 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.511 > 0.500)
# >face is NOT a Match (0.823 > 0.500)
# >face is a Match (0.131 <= 0.500)
# >face is NOT a Match (0.689 > 0.500)
# >face is a Match (0.272 <= 0.500)
# >face is NOT a Match (0.793 > 0.500)
# >face is NOT a Match (0.818 > 0.500)
# >face is a Match (0.417 <= 0.500)
# >face is a Match (0.488 <= 0.500)
# >face is a Match (0.374 <= 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.739 > 0.500)
# >face is NOT a Match (0.749 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is a Match (0.456 <= 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is a Match (0.327 <= 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is NOT a Match (0.541 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is a Match (0.289 <= 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is a Match (0.485 <= 0.500)
# >face is a Match (0.393 <= 0.500)
# >face is NOT a Match (0.742 > 0.500)
# >face is a Match (0.358 <= 0.500)
# >face is a Match (0.352 <= 0.500)
# >face is NOT a Match (0.664 > 0.500)
# >face is a Match (0.408 <= 0.500)
# >face is NOT a Match (0.663 > 0.500)
# >face is NOT a Match (0.681 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.795 > 0.500)
# >face is a Match (0.376 <= 0.500)
# >face is a Match (0.451 <= 0.500)
# >face is NOT a Match (0.576 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.651 > 0.500)
# >face is NOT a Match (0.734 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is a Match (0.218 <= 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is NOT a Match (0.552 > 0.500)
# >face is NOT a Match (0.825 > 0.500)
# >face is NOT a Match (0.656 > 0.500)
# >face is NOT a Match (0.724 > 0.500)
# >face is a Match (0.482 <= 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is a Match (0.256 <= 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is a Match (0.290 <= 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is a Match (0.414 <= 0.500)
# >face is a Match (0.204 <= 0.500)
# >face is a Match (0.330 <= 0.500)
# >face is a Match (0.192 <= 0.500)
# >face is NOT a Match (0.845 > 0.500)
# >face is NOT a Match (0.723 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is a Match (0.234 <= 0.500)
# >face is a Match (0.288 <= 0.500)
# >face is NOT a Match (0.738 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.680 > 0.500)
# >face is a Match (0.429 <= 0.500)
# >face is a Match (0.180 <= 0.500)
# >face is NOT a Match (0.719 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is a Match (0.185 <= 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is a Match (0.274 <= 0.500)
# >face is NOT a Match (0.823 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.781 > 0.500)
# >face is NOT a Match (0.746 > 0.500)
# >face is NOT a Match (0.654 > 0.500)
# >face is NOT a Match (0.839 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is a Match (0.388 <= 0.500)
# >face is a Match (0.204 <= 0.500)
# >face is a Match (0.141 <= 0.500)

# %%
TP=len([x for x in results if x[1]]) / len(results)
FN=1-TP

# %%
TP
# Out:
# 0.4056603773584906

# %%
FN
# Out:
# 0.5943396226415094

# %%
len(list(BASE_PATH.iterdir()))
# Out:
# 55

# %%
results_neg = []
count = 0

for person1 in BASE_PATH.iterdir():
    for person2 in BASE_PATH.iterdir():
        if not person1.is_dir() or not person2.is_dir() or person1.name == person2.name or not person1.name.isalpha() or not person2.name.isalpha():
            continue
        count += 1
        if count >= len(results):
            break
        index1 = index2 = 1
        
        path1 = BASE_PATH / person1.name / f'{person1.name}_{str(index1).rjust(4, "0")}.png'
        path2 = BASE_PATH / person2.name / f'{person2.name}_{str(index2).rjust(4, "0")}.png'

        try:
            features1,features2=get_embeddings([path1, path2])
            matched, distance = is_match(features1, features2)
        except Exception as e:
            print(e)
            continue

        results_neg.append([pair, matched, distance])
# Out:
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.563 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is NOT a Match (0.807 > 0.500)
# >face is NOT a Match (0.693 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.591 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.649 > 0.500)
# >face is NOT a Match (0.878 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.659 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.698 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.845 > 0.500)
# >face is NOT a Match (0.773 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.697 > 0.500)
# >face is NOT a Match (0.700 > 0.500)
# >face is NOT a Match (0.749 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.584 > 0.500)
# >face is NOT a Match (0.872 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.731 > 0.500)
# >face is NOT a Match (0.674 > 0.500)
# >face is NOT a Match (0.757 > 0.500)
# >face is NOT a Match (0.669 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.852 > 0.500)
# >face is NOT a Match (0.749 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.783 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is NOT a Match (0.844 > 0.500)
# >face is NOT a Match (0.644 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is NOT a Match (0.551 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.746 > 0.500)
# >face is NOT a Match (0.558 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.672 > 0.500)
# >face is NOT a Match (0.743 > 0.500)
# >face is NOT a Match (0.643 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.810 > 0.500)
# >face is NOT a Match (0.501 > 0.500)
# >face is NOT a Match (0.651 > 0.500)
# >face is NOT a Match (0.720 > 0.500)
# >face is NOT a Match (0.552 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is NOT a Match (0.691 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.644 > 0.500)
# >face is NOT a Match (0.653 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is NOT a Match (0.726 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.557 > 0.500)
# >face is NOT a Match (0.769 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.686 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.673 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.670 > 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.589 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.639 > 0.500)
# >face is NOT a Match (0.695 > 0.500)
# >face is NOT a Match (0.723 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.605 > 0.500)
# >face is a Match (0.431 <= 0.500)
# >face is NOT a Match (0.711 > 0.500)
# >face is NOT a Match (0.728 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.682 > 0.500)
# >face is NOT a Match (0.563 > 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.876 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.696 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.863 > 0.500)
# >face is NOT a Match (0.581 > 0.500)
# >face is NOT a Match (0.870 > 0.500)
# >face is NOT a Match (0.711 > 0.500)
# >face is NOT a Match (0.616 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.724 > 0.500)
# >face is NOT a Match (0.849 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.837 > 0.500)
# >face is NOT a Match (0.531 > 0.500)
# >face is NOT a Match (0.629 > 0.500)
# >face is NOT a Match (0.827 > 0.500)
# >face is NOT a Match (0.830 > 0.500)
# >face is NOT a Match (0.835 > 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is NOT a Match (0.535 > 0.500)
# >face is NOT a Match (0.724 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.736 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.737 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.818 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.854 > 0.500)
# >face is NOT a Match (0.856 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.746 > 0.500)
# >face is NOT a Match (0.876 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.857 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.832 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.734 > 0.500)
# >face is NOT a Match (0.807 > 0.500)
# >face is NOT a Match (0.699 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.828 > 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.878 > 0.500)
# >face is NOT a Match (0.673 > 0.500)
# >face is NOT a Match (0.737 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is NOT a Match (0.782 > 0.500)
# >face is NOT a Match (0.646 > 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.825 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.577 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.849 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.850 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.743 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.857 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.793 > 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.592 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.558 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is NOT a Match (0.742 > 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.566 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.625 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is a Match (0.454 <= 0.500)
# >face is NOT a Match (0.511 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.594 > 0.500)
# >face is NOT a Match (0.662 > 0.500)
# >face is NOT a Match (0.564 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.688 > 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is a Match (0.429 <= 0.500)
# >face is NOT a Match (0.697 > 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.599 > 0.500)
# >face is NOT a Match (0.632 > 0.500)
# >face is NOT a Match (0.739 > 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.697 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.608 > 0.500)
# >face is NOT a Match (0.596 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.718 > 0.500)
# >face is NOT a Match (0.621 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.633 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is NOT a Match (0.589 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.654 > 0.500)
# >face is NOT a Match (0.631 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.666 > 0.500)
# >face is NOT a Match (0.685 > 0.500)
# >face is NOT a Match (0.837 > 0.500)
# >face is NOT a Match (0.674 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.742 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.682 > 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.510 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.568 > 0.500)
# >face is NOT a Match (0.541 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.708 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.773 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.670 > 0.500)
# >face is NOT a Match (0.727 > 0.500)
# >face is NOT a Match (0.711 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.708 > 0.500)
# >face is NOT a Match (0.615 > 0.500)
# >face is NOT a Match (0.608 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.646 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.757 > 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is NOT a Match (0.713 > 0.500)
# >face is NOT a Match (0.807 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.857 > 0.500)
# >face is NOT a Match (0.722 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.818 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.745 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.756 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.834 > 0.500)
# >face is NOT a Match (0.778 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.782 > 0.500)
# >face is NOT a Match (0.667 > 0.500)
# >face is NOT a Match (0.842 > 0.500)
# >face is NOT a Match (0.783 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.773 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.634 > 0.500)
# >face is NOT a Match (0.781 > 0.500)
# >face is NOT a Match (0.759 > 0.500)
# >face is NOT a Match (0.833 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.782 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.817 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.764 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.693 > 0.500)
# >face is NOT a Match (0.641 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.765 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.629 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.717 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.843 > 0.500)
# >face is NOT a Match (0.662 > 0.500)
# >face is NOT a Match (0.661 > 0.500)
# >face is NOT a Match (0.827 > 0.500)
# >face is NOT a Match (0.842 > 0.500)
# >face is NOT a Match (0.794 > 0.500)
# >face is NOT a Match (0.834 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.654 > 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.639 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.739 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is NOT a Match (0.671 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.568 > 0.500)
# >face is NOT a Match (0.616 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.507 > 0.500)
# >face is NOT a Match (0.695 > 0.500)
# >face is a Match (0.470 <= 0.500)
# >face is NOT a Match (0.829 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.682 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.737 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.757 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.650 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.638 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.834 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.778 > 0.500)
# >face is NOT a Match (0.683 > 0.500)
# >face is NOT a Match (0.671 > 0.500)
# >face is NOT a Match (0.625 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.716 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.743 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.864 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.812 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.692 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.735 > 0.500)
# >face is NOT a Match (0.762 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.672 > 0.500)
# >face is NOT a Match (0.696 > 0.500)
# >face is NOT a Match (0.785 > 0.500)
# >face is NOT a Match (0.566 > 0.500)
# >face is NOT a Match (0.710 > 0.500)
# >face is NOT a Match (0.818 > 0.500)
# >face is NOT a Match (0.694 > 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is NOT a Match (0.828 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.835 > 0.500)
# >face is NOT a Match (0.650 > 0.500)
# >face is NOT a Match (0.623 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.738 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.601 > 0.500)
# >face is NOT a Match (0.721 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.626 > 0.500)
# >face is NOT a Match (0.712 > 0.500)
# >face is NOT a Match (0.692 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.510 > 0.500)
# >face is NOT a Match (0.533 > 0.500)
# >face is NOT a Match (0.688 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.692 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.667 > 0.500)
# >face is NOT a Match (0.739 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.611 > 0.500)
# >face is NOT a Match (0.719 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is NOT a Match (0.721 > 0.500)
# >face is NOT a Match (0.688 > 0.500)
# >face is NOT a Match (0.588 > 0.500)
# >face is NOT a Match (0.789 > 0.500)
# >face is NOT a Match (0.810 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.743 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.783 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.857 > 0.500)
# >face is NOT a Match (0.834 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.728 > 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.801 > 0.500)
# >face is NOT a Match (0.590 > 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is NOT a Match (0.752 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is NOT a Match (0.658 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.859 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.791 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.848 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.833 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.812 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.867 > 0.500)
# >face is NOT a Match (0.833 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.591 > 0.500)
# >face is NOT a Match (0.643 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.625 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.629 > 0.500)
# >face is NOT a Match (0.744 > 0.500)
# >face is NOT a Match (0.668 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.837 > 0.500)
# >face is NOT a Match (0.522 > 0.500)
# >face is NOT a Match (0.858 > 0.500)
# >face is NOT a Match (0.619 > 0.500)
# >face is NOT a Match (0.702 > 0.500)
# >face is NOT a Match (0.769 > 0.500)
# >face is a Match (0.483 <= 0.500)
# >face is NOT a Match (0.720 > 0.500)
# >face is NOT a Match (0.740 > 0.500)
# >face is NOT a Match (0.730 > 0.500)
# >face is NOT a Match (0.688 > 0.500)
# >face is NOT a Match (0.686 > 0.500)
# >face is NOT a Match (0.745 > 0.500)
# >face is NOT a Match (0.719 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.719 > 0.500)
# >face is NOT a Match (0.715 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.663 > 0.500)
# >face is NOT a Match (0.599 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.596 > 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.543 > 0.500)
# >face is NOT a Match (0.705 > 0.500)
# >face is NOT a Match (0.606 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.596 > 0.500)
# >face is NOT a Match (0.705 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.684 > 0.500)
# >face is NOT a Match (0.778 > 0.500)
# >face is NOT a Match (0.573 > 0.500)
# >face is NOT a Match (0.625 > 0.500)
# >face is NOT a Match (0.700 > 0.500)
# >face is NOT a Match (0.771 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.863 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.745 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.828 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.837 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.844 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.825 > 0.500)
# >face is NOT a Match (0.809 > 0.500)
# >face is NOT a Match (0.733 > 0.500)
# >face is NOT a Match (0.777 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.781 > 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.804 > 0.500)
# >face is NOT a Match (0.751 > 0.500)
# >face is NOT a Match (0.830 > 0.500)
# >face is NOT a Match (0.764 > 0.500)
# >face is NOT a Match (0.822 > 0.500)
# >face is NOT a Match (0.845 > 0.500)
# >face is NOT a Match (0.702 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.881 > 0.500)
# >face is NOT a Match (0.799 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.805 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.827 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.683 > 0.500)
# >face is NOT a Match (0.846 > 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.649 > 0.500)
# >face is NOT a Match (0.754 > 0.500)
# >face is NOT a Match (0.581 > 0.500)
# >face is NOT a Match (0.832 > 0.500)
# >face is NOT a Match (0.687 > 0.500)
# >face is NOT a Match (0.768 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.772 > 0.500)
# >face is NOT a Match (0.737 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.522 > 0.500)
# >face is NOT a Match (0.761 > 0.500)
# >face is NOT a Match (0.858 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.769 > 0.500)
# >face is NOT a Match (0.596 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.729 > 0.500)
# >face is NOT a Match (0.727 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.764 > 0.500)
# >face is NOT a Match (0.764 > 0.500)
# >face is NOT a Match (0.677 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.652 > 0.500)
# >face is NOT a Match (0.792 > 0.500)
# >face is NOT a Match (0.676 > 0.500)
# >face is NOT a Match (0.712 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.658 > 0.500)
# >face is NOT a Match (0.514 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.775 > 0.500)
# >face is NOT a Match (0.584 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.750 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.786 > 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.741 > 0.500)
# >face is NOT a Match (0.712 > 0.500)
# >face is NOT a Match (0.756 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.766 > 0.500)
# >face is NOT a Match (0.796 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.878 > 0.500)
# >face is NOT a Match (0.810 > 0.500)
# >face is NOT a Match (0.870 > 0.500)
# >face is NOT a Match (0.813 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.797 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.835 > 0.500)
# >face is NOT a Match (0.665 > 0.500)
# >face is NOT a Match (0.858 > 0.500)
# >face is NOT a Match (0.844 > 0.500)
# >face is NOT a Match (0.858 > 0.500)
# >face is NOT a Match (0.864 > 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is NOT a Match (0.815 > 0.500)
# >face is NOT a Match (0.836 > 0.500)
# >face is NOT a Match (0.817 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.756 > 0.500)
# >face is NOT a Match (0.833 > 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is NOT a Match (0.814 > 0.500)
# >face is NOT a Match (0.820 > 0.500)
# >face is NOT a Match (0.862 > 0.500)
# >face is NOT a Match (0.747 > 0.500)
# >face is NOT a Match (0.817 > 0.500)
# >face is NOT a Match (0.851 > 0.500)
# >face is NOT a Match (0.865 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.811 > 0.500)
# >face is NOT a Match (0.788 > 0.500)
# >face is NOT a Match (0.862 > 0.500)
# >face is NOT a Match (0.887 > 0.500)
# >face is NOT a Match (0.864 > 0.500)
# >face is NOT a Match (0.776 > 0.500)
# >face is NOT a Match (0.780 > 0.500)
# >face is NOT a Match (0.865 > 0.500)
# >face is NOT a Match (0.728 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.871 > 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is NOT a Match (0.816 > 0.500)
# >face is NOT a Match (0.826 > 0.500)
# >face is NOT a Match (0.856 > 0.500)
# >face is NOT a Match (0.824 > 0.500)
# >face is NOT a Match (0.845 > 0.500)
# >face is NOT a Match (0.875 > 0.500)
# >face is NOT a Match (0.812 > 0.500)
# >face is NOT a Match (0.845 > 0.500)
# >face is NOT a Match (0.862 > 0.500)
# >face is NOT a Match (0.790 > 0.500)
# >face is NOT a Match (0.501 > 0.500)
# >face is NOT a Match (0.711 > 0.500)
# >face is NOT a Match (0.734 > 0.500)
# >face is a Match (0.454 <= 0.500)
# >face is NOT a Match (0.704 > 0.500)
# >face is NOT a Match (0.756 > 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.757 > 0.500)
# >face is NOT a Match (0.650 > 0.500)
# >face is NOT a Match (0.783 > 0.500)
# >face is NOT a Match (0.619 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.709 > 0.500)
# >face is NOT a Match (0.864 > 0.500)
# >face is NOT a Match (0.591 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is a Match (0.477 <= 0.500)
# >face is NOT a Match (0.669 > 0.500)
# >face is NOT a Match (0.538 > 0.500)
# >face is NOT a Match (0.806 > 0.500)
# >face is NOT a Match (0.724 > 0.500)
# >face is NOT a Match (0.755 > 0.500)
# >face is NOT a Match (0.753 > 0.500)
# >face is NOT a Match (0.678 > 0.500)
# >face is NOT a Match (0.779 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.551 > 0.500)
# >face is NOT a Match (0.701 > 0.500)
# >face is NOT a Match (0.748 > 0.500)
# >face is NOT a Match (0.802 > 0.500)
# >face is NOT a Match (0.774 > 0.500)
# >face is NOT a Match (0.819 > 0.500)
# >face is NOT a Match (0.567 > 0.500)
# >face is NOT a Match (0.657 > 0.500)
# >face is NOT a Match (0.787 > 0.500)
# >face is NOT a Match (0.581 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.758 > 0.500)
# >face is NOT a Match (0.597 > 0.500)
# >face is NOT a Match (0.808 > 0.500)
# >face is NOT a Match (0.671 > 0.500)
# >face is NOT a Match (0.556 > 0.500)
# >face is NOT a Match (0.698 > 0.500)
# >face is NOT a Match (0.763 > 0.500)
# >face is NOT a Match (0.708 > 0.500)
# >face is NOT a Match (0.706 > 0.500)
# >face is NOT a Match (0.550 > 0.500)
# >face is NOT a Match (0.770 > 0.500)
# >face is NOT a Match (0.803 > 0.500)
# >face is NOT a Match (0.725 > 0.500)
# >face is NOT a Match (0.659 > 0.500)
# >face is NOT a Match (0.651 > 0.500)
# >face is NOT a Match (0.616 > 0.500)
# >face is NOT a Match (0.807 > 0.500)
# >face is NOT a Match (0.511 > 0.500)
# >face is NOT a Match (0.510 > 0.500)
# >face is NOT a Match (0.800 > 0.500)
# >face is NOT a Match (0.767 > 0.500)
# >face is NOT a Match (0.675 > 0.500)
# >face is NOT a Match (0.623 > 0.500)
# >face is NOT a Match (0.798 > 0.500)
# >face is NOT a Match (0.702 > 0.500)
# >face is NOT a Match (0.821 > 0.500)
# >face is NOT a Match (0.703 > 0.500)
# >face is NOT a Match (0.824 > 0.500)

# %%
FP=len([x for x in results_neg if x[1]]) / len(results_neg)
TN=1-FP

# %%
FP
# Out:
# 0.008264462809917356

# %%
TN
# Out:
# 0.9917355371900827

# %%
TP=len([x for x in results if x[1]]) / (len(results) + len(results_neg))
FN=len([x for x in results if not x[1]]) / (len(results) + len(results_neg))
FP=len([x for x in results_neg if x[1]]) / (len(results) + len(results_neg))
TN=len([x for x in results_neg if not x[1]]) / (len(results) + len(results_neg))
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [[TP,FN],
         [FP,TN]]

df_cm = pd.DataFrame(array, ['same', 'different'], ['verified', 'unverified'])
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %%
from sklearn import svm
X = [x[2] for x in results] + [x[2] for x in results_neg]
y = [1 for x in results] + [0 for x in results_neg]
clf = svm.SVC()
clf.fit(np.array(X).reshape(-1, 1), y)
# Out:
# SVC()

# %%
ps=clf.predict(np.array([x[2] for x in results]).reshape(-1, 1))

# %%
len([x for x in ps if x == 1])
# Out:
# 409

# %%
ns=clf.predict(np.array([x[2] for x in results_neg]).reshape(-1, 1))

# %%
np.array([x[2] for x in results + results_neg])
# Out:
# array([0.24841452, 0.74076822, 0.76090106, ..., 0.82123597, 0.70314679,
#        0.82381544])

# %%
len([x for x in ps if x == 0])
# Out:
# 439

# %%
len(ps)
# Out:
# 848

# %%
TP=len([x for x in ps if x]) / (len(results) + len(results_neg))
FN=len([x for x in ps if not x]) / (len(results) + len(results_neg))
FP=len([x for x in ns if x]) / (len(results) + len(results_neg))
TN=len([x for x in ns if not x]) / (len(results) + len(results_neg))
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [[TP,FN],
         [FP,TN]]

df_cm = pd.DataFrame(array, ['same', 'different'], ['verified', 'unverified'])
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %%
TP
# Out:
# 0.24129793510324485

# %%
FN
# Out:
# 0.25899705014749264

# %%
FP
# Out:
# 0.024778761061946902

# %%
len(results) + len(results_neg)
# Out:
# 1695
